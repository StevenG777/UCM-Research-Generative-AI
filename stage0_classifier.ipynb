# %%
# Import Library
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.transforms as transforms
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.utils.data import DataLoader, Dataset

import pandas as pd
from PIL import Image
from sklearn.metrics import confusion_matrix, precision_recall_fscore_support
# Out:
# /opt/homebrew/anaconda3/lib/python3.10/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: dlopen(/opt/homebrew/anaconda3/lib/python3.10/site-packages/torchvision/image.so, 0x0006): Symbol not found: __ZN2at4_ops19empty_memory_format4callEN3c108ArrayRefIxEENS2_8optionalINS2_10ScalarTypeEEENS5_INS2_6LayoutEEENS5_INS2_6DeviceEEENS5_IbEENS5_INS2_12MemoryFormatEEE
#   Referenced from: <F0D48035-EF9E-3141-9F63-566920E60D7C> /opt/homebrew/anaconda3/lib/python3.10/site-packages/torchvision/image.so
#   Expected in:     <9DDA9B08-547F-32F9-87F1-796977059897> /opt/homebrew/anaconda3/lib/python3.10/site-packages/torch/lib/libtorch_cpu.dylib
#   warn(f"Failed to load image Python extension: {e}")

# %%
# Apple GPU Availability Verfication
if not torch.backends.mps.is_available():
    if not torch.backends.mps.is_built():
        print("MPS not available because the current PyTorch install was not "
              "built with MPS enabled.")
    else:
        print("MPS not available because the current MacOS version is not 12.3+ "
              "and/or you do not have an MPS-enabled device on this machine.")
else:
    mps = True
    print("Apple GPU is available")
# Out:
# Apple GPU is available

# %%
# CustomImageDataset & DataLoader
torch.manual_seed(42)
epochs = 100
batch_size = 512

# Define Custom Image Dataset Class
class CustomImageDataset(Dataset):
    def __init__(self, annotations_file):
        self.img_labels = pd.read_csv(annotations_file)
        self.transform = transforms.Compose([
            transforms.Resize((32, 32)),
            transforms.ToTensor(),
            # transforms.Normalize(mean=[0.5], std=[0.5]),
            # transforms.Lambda(lambda x: (x + 1.0) / 2.0)
        ])

    def __len__(self):
        return len(self.img_labels)

    def __getitem__(self, idx):
        img_path = self.img_labels.iloc[idx, 0]
        image = Image.open(img_path)
        image = self.transform(image)
        label = self.img_labels.iloc[idx, 1]
        return image, label

# Call the CID object
csv_file = "train_data.csv"
cid = CustomImageDataset(csv_file)

# Define Dataloader
train_loader = DataLoader(
    cid,
    batch_size=batch_size,
    shuffle=True,
    drop_last=True,
)

csv_file = "test_data.csv"
cid = CustomImageDataset(csv_file)

test_loader = DataLoader(
    cid,
    batch_size=batch_size,
    shuffle=True,
    drop_last=True,
)

# %%
# Define CNN Architecture
class Classifier(nn.Module):
    def __init__(self, num_classes):
        super(Classifier, self).__init__()
        self.model = nn.Sequential(
            nn.Conv2d(1, 64, kernel_size=2),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(64, 128, kernel_size=2),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            
            nn.MaxPool2d(kernel_size=2, stride=2),  
            nn.Conv2d(128, 256, kernel_size=2),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(256, 512, kernel_size=2),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        self.fc = nn.Linear(512, num_classes)

    def forward(self, x):
        x = self.model(x)
        x = x.view(x.size(0), -1)
        x = self.fc(x)
        return x

# %%
# Initialize Model, Loss Function, Optimizer and Scheduler
model = Classifier(num_classes=5)
criterion = nn.CrossEntropyLoss(weight=torch.tensor([0.163, 0.158, 0.287, 0.193, 0.197]))
optimizer = optim.Adam(model.parameters(), lr=0.001)
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=2, verbose=True, min_lr=1e-6)

# Switch to GPU/CPU
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
model.to(device)
criterion.to(device)
# Out:
# CrossEntropyLoss()

# %%
# Model Training & Validation
num_epochs = 20

train_losses = []
train_accuracies = []
valid_losses = []
valid_accuracies = []

true_label = []
pred_label = []

for epoch in range(1, num_epochs + 1):
    # Starting Training
    model.train()
    correct = 0
    total = 0
    loss = 0.0
    
    for step, (vector, label) in enumerate(train_loader):
        # Switch to GPU/CPU
        vector = vector.to(device)
        label = label.to(device)
        
        # Clear Gradient --> Prevent Accumulating Previous Gradient
        optimizer.zero_grad()
        
        # Forward Pass --> Generate Predicted Output(Max Probability Class) from CNN
        logits = model(vector)
        _, predicted = torch.max(logits.data, 1)
        
        # Backward Propagation & Update Parameter --> Optimizer To Fit CNN
        loss = criterion(logits, label)
        loss.backward()
        optimizer.step()
        
        # Accumulate Training Loss, # of Correct Prediction & # of Label 
        total += label.size(0)
        loss += loss.item()
        correct += (predicted == label).sum().item()
        
        # Save Results for Confusion Matrix
        true_label.extend(label.tolist())
        pred_label.extend(predicted.tolist())

        print(loss)

    # Average Training Loss & Calculate Training Accuracy
    epoch_train_loss = loss / len(train_loader)
    epoch_train_accuracy = 100 * correct / total
    
    # Print & Save Results for Plot
    train_losses.append(epoch_train_loss)
    train_accuracies.append(epoch_train_accuracy)
    print(f'Epoch [{epoch}/{num_epochs}], Train Loss: {epoch_train_loss:.4f}, Train Accuracy: {epoch_train_accuracy:.2f}%')
    
    #----------------------------------------------------------------------------------------------------------------------
    
    # Start Validating
    model.eval()
    correct = 0
    total = 0
    valid_loss = 0.0

    with torch.no_grad():
        for vector, label in test_loader:
            # Switch to GPU/CPU
            vector = vector.to(device)
            label = label.to(device)
            
            # Forward Pass & Produce Output
            pred = model(vector)
            _, predicted = torch.max(pred.data, 1)

            # Accumulate Validation Loss, # of Correct Prediction, # of Labels
            total += label.size(0)
            loss = criterion(pred, label)
            valid_loss += loss.item()
            correct += (predicted == label).sum().item()
            
            # Save Results for Confusion Matrix
            true_label.extend(label.tolist())
            pred_label.extend(predicted.tolist())
    
    # Average Validation Loss & Calculate Validation Accuracy
    epoch_valid_loss = loss / len(test_loader)
    epoch_valid_accuracy = 100 * correct / total

    # Print & Save Results for Plot
    valid_losses.append(epoch_valid_loss)
    valid_accuracies.append(epoch_valid_accuracy)
    print(f'Epoch [{epoch}/{num_epochs}], Validation Loss: {epoch_valid_loss:.4f}, Validation Accuracy: {epoch_valid_accuracy:.2f}%')
   
    # Activate Scheduler
    scheduler.step(epoch_valid_loss)
# Out:
# tensor(3.8323, device='mps:0', grad_fn=<AddBackward0>)
# tensor(3.8730, device='mps:0', grad_fn=<AddBackward0>)
# tensor(3.2008, device='mps:0', grad_fn=<AddBackward0>)
# tensor(3.5105, device='mps:0', grad_fn=<AddBackward0>)
# tensor(3.0338, device='mps:0', grad_fn=<AddBackward0>)
# tensor(3.0146, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.9143, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.9160, device='mps:0', grad_fn=<AddBackward0>)
# tensor(3.0519, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.8937, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.8929, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.8140, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.8047, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.7941, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.7738, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.5972, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.7203, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.6509, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.6096, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.7992, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.6884, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.6442, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.6088, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.5441, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.5382, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.6576, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.5992, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.6307, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.6237, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.5198, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.5424, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.4691, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.3766, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.4765, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.5266, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.5564, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.4975, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.4286, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.5005, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.4348, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.3473, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.3820, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.6766, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.4912, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.4867, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.4013, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.3829, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.3871, device='mps:0', grad_fn=<AddBackward0>)
# Epoch [1/20], Train Loss: 0.0497, Train Accuracy: 38.90%
# Epoch [1/20], Validation Loss: 0.1092, Validation Accuracy: 39.37%
# tensor(2.2337, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.2892, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.2751, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.1738, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.1794, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.1488, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.1809, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.1453, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.2090, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.1366, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.1893, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.2896, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.2433, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.1620, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.1079, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.0742, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.2085, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.2142, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.1436, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.2162, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.0787, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.1586, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.2445, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.1386, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.3037, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.0189, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.1277, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.2281, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.2626, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.1368, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.1651, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.1913, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.1495, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.2750, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.2158, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.0854, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.0740, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.2749, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.0933, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.0459, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.2102, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.0585, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.8306, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.1659, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.1361, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.2947, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.2512, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.1090, device='mps:0', grad_fn=<AddBackward0>)
# Epoch [2/20], Train Loss: 0.0439, Train Accuracy: 51.92%
# Epoch [2/20], Validation Loss: 0.1061, Validation Accuracy: 46.74%
# tensor(1.9253, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.9914, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.9385, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.7340, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.0102, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.1032, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.8223, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.7891, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.9720, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.9047, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.0469, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.9232, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.7992, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.0289, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.8442, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.9420, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.8208, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.9279, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.9022, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.8463, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.8759, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.9556, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.8936, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.7916, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.0015, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.7796, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.9319, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.9393, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.0661, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.9033, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.9959, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.8882, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.9181, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.8513, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.9188, device='mps:0', grad_fn=<AddBackward0>)
# tensor(2.0223, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.8941, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.9782, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.7523, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.8943, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.9038, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.9233, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.7584, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.9197, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.8780, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.9603, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.9185, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.8408, device='mps:0', grad_fn=<AddBackward0>)
# Epoch [3/20], Train Loss: 0.0383, Train Accuracy: 58.75%
# Epoch [3/20], Validation Loss: 0.1064, Validation Accuracy: 45.87%
# tensor(1.8349, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.7103, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.7057, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.7042, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.8239, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.7729, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.6394, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.6644, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.6593, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.6631, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.7182, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.6471, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.7183, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.7127, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.6826, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.7501, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.5677, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.7620, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.7680, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.7470, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.6602, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.6496, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.5433, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.6384, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.6940, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.6916, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.5254, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.7056, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.7025, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.6037, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.7220, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.6525, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.7413, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.5802, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.6212, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.6412, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.6799, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.7718, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.6912, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.6609, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.6740, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.7854, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.7749, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.7175, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.8698, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.7733, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.7174, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.7184, device='mps:0', grad_fn=<AddBackward0>)
# Epoch [4/20], Train Loss: 0.0358, Train Accuracy: 63.77%
# Epoch [4/20], Validation Loss: 0.0864, Validation Accuracy: 50.54%
# tensor(1.5877, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.6056, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.5432, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.4788, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.4597, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.4390, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.4804, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.4904, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.4937, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.4803, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.4177, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.4674, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.6156, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.4571, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.4597, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.5085, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.3301, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.4037, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.4148, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.4453, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.4754, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.4078, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.4034, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.4961, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.3808, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.4496, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.4352, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.4564, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.4418, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.4835, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.5515, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.4850, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.3902, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.5510, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.5475, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.4741, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.6272, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.5485, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.4500, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.4294, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.5488, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.4783, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.5300, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.5551, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.6197, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.5740, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.5805, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.5194, device='mps:0', grad_fn=<AddBackward0>)
# Epoch [5/20], Train Loss: 0.0317, Train Accuracy: 68.73%
# Epoch [5/20], Validation Loss: 0.0833, Validation Accuracy: 55.00%
# tensor(1.1921, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.3061, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.2459, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.2264, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.2181, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.2215, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.2448, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.1989, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.1545, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.2636, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.2368, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.1831, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.1630, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.2745, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.1721, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.1880, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.2442, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.2655, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.1697, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.1244, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.3333, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.2672, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.1755, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.2713, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.1651, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.2802, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.2977, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.2064, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.1821, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.3939, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.3200, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.2532, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.2227, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.2712, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.2594, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.2870, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.4339, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.2117, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.2411, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.2492, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.3690, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.1846, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.2387, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.3439, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.3078, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.2259, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.2197, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.2236, device='mps:0', grad_fn=<AddBackward0>)
# Epoch [6/20], Train Loss: 0.0255, Train Accuracy: 74.96%
# Epoch [6/20], Validation Loss: 0.1040, Validation Accuracy: 51.92%
# tensor(1.0244, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.0275, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.0750, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.0069, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.9450, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.9020, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.0630, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.9379, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.9526, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.9764, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.8879, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.9514, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.0247, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.0163, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.9593, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.9122, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.9693, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.0475, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.0575, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.9219, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.0071, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.9561, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.9746, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.9151, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.9993, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.9321, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.0307, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.9933, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.0509, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.1014, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.9435, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.0482, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.0092, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.0078, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.9765, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.9651, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.9731, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.1058, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.0437, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.0506, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.1109, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.1665, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.0100, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.9757, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.2259, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.0428, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.0656, device='mps:0', grad_fn=<AddBackward0>)
# tensor(1.1127, device='mps:0', grad_fn=<AddBackward0>)
# Epoch [7/20], Train Loss: 0.0232, Train Accuracy: 80.28%
# Epoch [7/20], Validation Loss: 0.0942, Validation Accuracy: 55.50%
# tensor(0.8414, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.8013, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.8790, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.8444, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.7332, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.8244, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.7831, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.7097, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.7817, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.7945, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.7416, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.7898, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.7736, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.7093, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.7320, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.7339, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.8478, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.7919, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.7701, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.6980, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.7757, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.7990, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.8295, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.8152, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.8861, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.8011, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.7842, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.8063, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.6480, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.8017, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.8345, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.8290, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.8530, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.8042, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.7885, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.8766, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.8528, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.7395, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.7092, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.8106, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.7304, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.7731, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.8546, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.7945, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.8076, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.8961, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.8764, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.8063, device='mps:0', grad_fn=<AddBackward0>)
# Epoch [8/20], Train Loss: 0.0168, Train Accuracy: 85.69%
# Epoch [8/20], Validation Loss: 0.1193, Validation Accuracy: 52.13%
# Epoch 00008: reducing learning rate of group 0 to 1.0000e-04.
# tensor(0.6089, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.6087, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.5523, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.4975, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.6171, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.5296, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.5198, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.4864, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.5486, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.5650, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.5272, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.4304, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.4985, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.4806, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.5069, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.4628, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.4389, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.4255, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.4920, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.4658, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.4302, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.4518, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.4543, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.4364, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.5089, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.4292, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.4693, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.5046, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.4331, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.4491, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.4367, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.4675, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.4328, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.4469, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.4124, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.4554, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.4274, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.4345, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.4307, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.5106, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.4300, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.4035, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3920, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.4462, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.4015, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.4426, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3875, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.4008, device='mps:0', grad_fn=<AddBackward0>)
# Epoch [9/20], Train Loss: 0.0083, Train Accuracy: 94.49%
# Epoch [9/20], Validation Loss: 0.0987, Validation Accuracy: 58.41%
# tensor(0.3625, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3992, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3869, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3583, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3843, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3987, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3938, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3803, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3922, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3423, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3809, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3766, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3621, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3805, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3851, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3747, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.4109, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3669, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.4408, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3086, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3718, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3955, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3768, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3601, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3813, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3737, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3855, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3933, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3425, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3616, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3777, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3836, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3717, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3720, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3765, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3942, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3747, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3560, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3952, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3350, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3591, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3875, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3796, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3969, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3968, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.4026, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.4042, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3806, device='mps:0', grad_fn=<AddBackward0>)
# Epoch [10/20], Train Loss: 0.0079, Train Accuracy: 96.34%
# Epoch [10/20], Validation Loss: 0.0997, Validation Accuracy: 58.45%
# tensor(0.3529, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2966, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3302, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3278, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3605, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3520, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3071, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3115, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3126, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3014, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3554, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3418, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3232, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3515, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3385, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3268, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3351, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3164, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3078, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3475, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3825, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3045, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3114, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3632, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3273, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3239, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3317, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3406, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3559, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3356, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3599, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3099, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3535, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3296, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3510, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3465, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3494, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3300, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3458, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3383, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3483, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3817, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3758, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3641, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3577, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3096, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3353, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3489, device='mps:0', grad_fn=<AddBackward0>)
# Epoch [11/20], Train Loss: 0.0073, Train Accuracy: 97.19%
# Epoch [11/20], Validation Loss: 0.0902, Validation Accuracy: 57.91%
# Epoch 00011: reducing learning rate of group 0 to 1.0000e-05.
# tensor(0.3334, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3169, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3196, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3001, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3519, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3150, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3410, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2861, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3231, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2809, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2967, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3296, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3034, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2947, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3070, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2880, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3005, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2775, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3085, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3136, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2905, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2938, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3089, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2891, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3019, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3298, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2984, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2747, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2811, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2989, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2779, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2912, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2965, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3032, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3310, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3027, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3142, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3125, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3010, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3208, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2939, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2615, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3241, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3131, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3040, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3012, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3014, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2984, device='mps:0', grad_fn=<AddBackward0>)
# Epoch [12/20], Train Loss: 0.0062, Train Accuracy: 97.75%
# Epoch [12/20], Validation Loss: 0.0989, Validation Accuracy: 58.24%
# tensor(0.3054, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3145, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3155, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3280, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2940, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3370, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3029, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2885, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2899, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2905, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2927, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3227, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2943, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3209, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3329, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3121, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2912, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2824, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2607, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2745, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3083, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2994, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2831, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3033, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3040, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2953, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2924, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2984, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2889, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2966, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2982, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2748, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3087, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3132, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2916, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3133, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2966, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3150, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2558, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3125, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2882, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2651, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2877, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3066, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3148, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2744, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3338, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3015, device='mps:0', grad_fn=<AddBackward0>)
# Epoch [13/20], Train Loss: 0.0063, Train Accuracy: 97.97%
# Epoch [13/20], Validation Loss: 0.0932, Validation Accuracy: 58.54%
# tensor(0.2964, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2789, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3266, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2884, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2703, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2711, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3123, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3234, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2850, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3065, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2967, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3027, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2973, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2856, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2814, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3156, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3199, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2617, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3007, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2676, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3245, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3048, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2925, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3160, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2942, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2984, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3101, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3290, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2644, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2991, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3107, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2817, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3029, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2801, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2539, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2994, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3096, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2709, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2861, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3185, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3291, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2740, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3283, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2950, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3022, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3178, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2880, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2886, device='mps:0', grad_fn=<AddBackward0>)
# Epoch [14/20], Train Loss: 0.0060, Train Accuracy: 97.99%
# Epoch [14/20], Validation Loss: 0.0966, Validation Accuracy: 58.50%
# Epoch 00014: reducing learning rate of group 0 to 1.0000e-06.
# tensor(0.3111, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3052, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3065, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2975, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2812, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2802, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2895, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3084, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2706, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2765, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2573, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3324, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3184, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3236, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3001, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2693, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2723, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2888, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2859, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2801, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2706, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2770, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3144, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2709, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3116, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2786, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3013, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3060, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3019, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2633, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2910, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2801, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3120, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2944, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3243, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3170, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2645, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2835, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3119, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2937, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2950, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3404, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2778, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2764, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3236, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2944, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2829, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2840, device='mps:0', grad_fn=<AddBackward0>)
# Epoch [15/20], Train Loss: 0.0059, Train Accuracy: 98.06%
# Epoch [15/20], Validation Loss: 0.0927, Validation Accuracy: 58.45%
# tensor(0.3086, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2789, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2793, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2798, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3146, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2945, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2980, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3073, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3032, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3006, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3106, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3011, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3175, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2869, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3111, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2771, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2918, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2590, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3218, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2554, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2688, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2821, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3033, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3345, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3014, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2935, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3063, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2896, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3114, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2916, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3212, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2808, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3237, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3000, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2824, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3007, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2675, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2577, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3048, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2827, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2790, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2953, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3062, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2933, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3283, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2639, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2608, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2754, device='mps:0', grad_fn=<AddBackward0>)
# Epoch [16/20], Train Loss: 0.0057, Train Accuracy: 98.05%
# Epoch [16/20], Validation Loss: 0.0895, Validation Accuracy: 58.48%
# tensor(0.3050, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2723, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2570, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2999, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2764, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2884, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2878, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2801, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2915, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2615, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3156, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2965, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2921, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3194, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3036, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2604, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2983, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2915, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3336, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2686, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2990, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3118, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2832, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2896, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3030, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3117, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3087, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2833, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3079, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3083, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2638, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2747, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2941, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2609, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2808, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3096, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2940, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2511, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3126, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2712, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2986, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2811, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3017, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2942, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3227, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3429, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3533, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2905, device='mps:0', grad_fn=<AddBackward0>)
# Epoch [17/20], Train Loss: 0.0061, Train Accuracy: 98.02%
# Epoch [17/20], Validation Loss: 0.0966, Validation Accuracy: 58.46%
# tensor(0.2774, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2858, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2829, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3141, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3135, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2800, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2908, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3083, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2891, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3013, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2990, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2878, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2704, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3098, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3184, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3072, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2768, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3346, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2966, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2985, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2877, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2849, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3061, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3099, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2782, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3099, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2960, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2950, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2981, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2739, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2812, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2826, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2892, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2599, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2932, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2753, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2826, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2845, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2677, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3051, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2948, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3542, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2861, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2596, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2839, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2771, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2827, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3058, device='mps:0', grad_fn=<AddBackward0>)
# Epoch [18/20], Train Loss: 0.0064, Train Accuracy: 98.05%
# Epoch [18/20], Validation Loss: 0.1019, Validation Accuracy: 58.54%
# tensor(0.2838, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3315, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2854, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2905, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2581, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3283, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3004, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3061, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2820, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2759, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2805, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2949, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2736, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2739, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3046, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2987, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2715, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2907, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2820, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3329, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2955, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2970, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3262, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2886, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2870, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3023, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3435, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2777, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2930, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3034, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2836, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2847, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3051, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3219, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2893, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3044, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3079, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2738, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2710, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2898, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2608, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2760, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2831, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2636, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2992, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2675, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2824, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3426, device='mps:0', grad_fn=<AddBackward0>)
# Epoch [19/20], Train Loss: 0.0071, Train Accuracy: 98.06%
# Epoch [19/20], Validation Loss: 0.0989, Validation Accuracy: 58.28%
# tensor(0.2538, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2952, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3024, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2873, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3134, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2834, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2947, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2872, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2935, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2967, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2605, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2909, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3046, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3155, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2797, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2956, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3144, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2847, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2984, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2590, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3128, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2890, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2673, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3158, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3019, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2579, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3257, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3025, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2681, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3079, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2848, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2937, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2751, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2741, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2723, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2878, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2609, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2841, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2924, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3302, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3584, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2813, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3026, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3198, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2656, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.3056, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2802, device='mps:0', grad_fn=<AddBackward0>)
# tensor(0.2777, device='mps:0', grad_fn=<AddBackward0>)
# Epoch [20/20], Train Loss: 0.0058, Train Accuracy: 98.07%
# Epoch [20/20], Validation Loss: 0.0940, Validation Accuracy: 58.30%

# %%
# Model Evaluation
print("Confusion Matrix:")
print(confusion_matrix(true_label, pred_label))

precision, recall, f1, _ = precision_recall_fscore_support(true_label, pred_label, average='micro')
print(f"Precision: {precision:.4f}, Recall: {recall:.4f}, F1-Score: {f1:.4f}")
# Out:
# Confusion Matrix:
# [[ 67741   4919   8601  11236   7764]
#  [  4134  67056   8750   9013   8199]
#  [  1548   1543 164911   3983   4294]
#  [  5088   4143  10282  88260  11352]
#  [  3043   3355  10728   8905  95552]]
# Precision: 0.7870, Recall: 0.7870, F1-Score: 0.7870
